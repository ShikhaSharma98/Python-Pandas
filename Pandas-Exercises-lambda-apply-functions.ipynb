# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
student_mat=pd.read_csv("Exercise Data Files/Pandas Exercise Lambda Functions Files/student-mat.csv")
student_por=pd.read_csv("Exercise Data Files/Pandas Exercise Lambda Functions Files/student-por.csv")
df = pd.merge(left = student_por,
               right = student_mat,
               left_on = 'school',
               right_on = 'school',
               how = 'inner')

df.head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F     18         U       GT3         A       4       4  at_home
# 1     GP     F     18         U       GT3         A       4       4  at_home
# 2     GP     F     18         U       GT3         A       4       4  at_home
# 3     GP     F     18         U       GT3         A       4       4  at_home
# 4     GP     F     18         U       GT3         A       4       4  at_home
#
#     Fjob_x ...  famrel_y freetime_y  goout_y  Dalc_y  Walc_y health_y  \
# 0  teacher ...         4          3        4       1       1        3
# 1  teacher ...         5          3        3       1       1        3
# 2  teacher ...         4          3        2       2       3        3
# 3  teacher ...         3          2        2       1       1        5
# 4  teacher ...         4          3        2       1       2        5
#
#   absences_y G1_y G2_y G3_y
# 0          6    5    6    6
# 1          4    5    5    6
# 2         10    7    8   10
# 3          2   15   14   15
# 4          4    6   10   10
#
# [5 rows x 65 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 0          GP     F     18         U       GT3         A       4       4
# 1          GP     F     18         U       GT3         A       4       4
# 2          GP     F     18         U       GT3         A       4       4
# 3          GP     F     18         U       GT3         A       4       4
# 4          GP     F     18         U       GT3         A       4       4
# 5          GP     F     18         U       GT3         A       4       4
# 6          GP     F     18         U       GT3         A       4       4
# 7          GP     F     18         U       GT3         A       4       4
# 8          GP     F     18         U       GT3         A       4       4
# 9          GP     F     18         U       GT3         A       4       4
# 10         GP     F     18         U       GT3         A       4       4
# 11         GP     F     18         U       GT3         A       4       4
# 12         GP     F     18         U       GT3         A       4       4
# 13         GP     F     18         U       GT3         A       4       4
# 14         GP     F     18         U       GT3         A       4       4
# 15         GP     F     18         U       GT3         A       4       4
# 16         GP     F     18         U       GT3         A       4       4
# 17         GP     F     18         U       GT3         A       4       4
# 18         GP     F     18         U       GT3         A       4       4
# 19         GP     F     18         U       GT3         A       4       4
# 20         GP     F     18         U       GT3         A       4       4
# 21         GP     F     18         U       GT3         A       4       4
# 22         GP     F     18         U       GT3         A       4       4
# 23         GP     F     18         U       GT3         A       4       4
# 24         GP     F     18         U       GT3         A       4       4
# 25         GP     F     18         U       GT3         A       4       4
# 26         GP     F     18         U       GT3         A       4       4
# 27         GP     F     18         U       GT3         A       4       4
# 28         GP     F     18         U       GT3         A       4       4
# 29         GP     F     18         U       GT3         A       4       4
# ...       ...   ...    ...       ...       ...       ...     ...     ...
# 157993     MS     M     18         R       LE3         T       3       2
# 157994     MS     M     18         R       LE3         T       3       2
# 157995     MS     M     18         R       LE3         T       3       2
# 157996     MS     M     18         R       LE3         T       3       2
# 157997     MS     M     18         R       LE3         T       3       2
# 157998     MS     M     18         R       LE3         T       3       2
# 157999     MS     M     18         R       LE3         T       3       2
# 158000     MS     M     18         R       LE3         T       3       2
# 158001     MS     M     18         R       LE3         T       3       2
# 158002     MS     M     18         R       LE3         T       3       2
# 158003     MS     M     18         R       LE3         T       3       2
# 158004     MS     M     18         R       LE3         T       3       2
# 158005     MS     M     18         R       LE3         T       3       2
# 158006     MS     M     18         R       LE3         T       3       2
# 158007     MS     M     18         R       LE3         T       3       2
# 158008     MS     M     18         R       LE3         T       3       2
# 158009     MS     M     18         R       LE3         T       3       2
# 158010     MS     M     18         R       LE3         T       3       2
# 158011     MS     M     18         R       LE3         T       3       2
# 158012     MS     M     18         R       LE3         T       3       2
# 158013     MS     M     18         R       LE3         T       3       2
# 158014     MS     M     18         R       LE3         T       3       2
# 158015     MS     M     18         R       LE3         T       3       2
# 158016     MS     M     18         R       LE3         T       3       2
# 158017     MS     M     18         R       LE3         T       3       2
# 158018     MS     M     18         R       LE3         T       3       2
# 158019     MS     M     18         R       LE3         T       3       2
# 158020     MS     M     18         R       LE3         T       3       2
# 158021     MS     M     18         R       LE3         T       3       2
# 158022     MS     M     18         R       LE3         T       3       2
#
#           Mjob_x   Fjob_x  ...   freetime_y goout_y  Dalc_y  Walc_y  health_y  \
# 0        at_home  teacher  ...            3       4       1       1         3
# 1        at_home  teacher  ...            3       3       1       1         3
# 2        at_home  teacher  ...            3       2       2       3         3
# 3        at_home  teacher  ...            2       2       1       1         5
# 4        at_home  teacher  ...            3       2       1       2         5
# 5        at_home  teacher  ...            4       2       1       2         5
# 6        at_home  teacher  ...            4       4       1       1         3
# 7        at_home  teacher  ...            1       4       1       1         1
# 8        at_home  teacher  ...            2       2       1       1         1
# 9        at_home  teacher  ...            5       1       1       1         5
# 10       at_home  teacher  ...            3       3       1       2         2
# 11       at_home  teacher  ...            2       2       1       1         4
# 12       at_home  teacher  ...            3       3       1       3         5
# 13       at_home  teacher  ...            4       3       1       2         3
# 14       at_home  teacher  ...            5       2       1       1         3
# 15       at_home  teacher  ...            4       4       1       2         2
# 16       at_home  teacher  ...            2       3       1       2         2
# 17       at_home  teacher  ...            3       2       1       1         4
# 18       at_home  teacher  ...            5       5       2       4         5
# 19       at_home  teacher  ...            1       3       1       3         5
# 20       at_home  teacher  ...            4       1       1       1         1
# 21       at_home  teacher  ...            4       2       1       1         5
# 22       at_home  teacher  ...            5       1       1       3         5
# 23       at_home  teacher  ...            4       4       2       4         5
# 24       at_home  teacher  ...            3       2       1       1         5
# 25       at_home  teacher  ...            2       2       1       3         5
# 26       at_home  teacher  ...            2       2       1       2         5
# 27       at_home  teacher  ...            2       4       2       4         1
# 28       at_home  teacher  ...            3       3       1       1         5
# 29       at_home  teacher  ...            4       5       5       5         5
# ...          ...      ...  ...          ...     ...     ...     ...       ...
# 157993  services    other  ...            3       4       2       4         3
# 157994  services    other  ...            2       2       2       2         5
# 157995  services    other  ...            2       1       1       2         1
# 157996  services    other  ...            2       3       1       2         4
# 157997  services    other  ...            2       2       4       2         5
# 157998  services    other  ...            2       2       1       1         3
# 157999  services    other  ...            3       3       2       3         3
# 158000  services    other  ...            4       3       1       1         3
# 158001  services    other  ...            5       5       1       3         1
# 158002  services    other  ...            4       4       1       1         1
# 158003  services    other  ...            3       2       1       2         4
# 158004  services    other  ...            4       3       1       1         3
# 158005  services    other  ...            4       3       3       4         2
# 158006  services    other  ...            1       3       1       2         1
# 158007  services    other  ...            5       4       2       3         1
# 158008  services    other  ...            2       4       1       4         2
# 158009  services    other  ...            4       3       1       3         5
# 158010  services    other  ...            4       3       1       1         3
# 158011  services    other  ...            3       2       1       3         5
# 158012  services    other  ...            4       3       4       3         3
# 158013  services    other  ...            3       3       1       3         4
# 158014  services    other  ...            4       3       2       2         5
# 158015  services    other  ...            4       2       1       2         5
# 158016  services    other  ...            3       4       1       1         1
# 158017  services    other  ...            1       1       1       1         5
# 158018  services    other  ...            5       4       4       5         4
# 158019  services    other  ...            4       5       3       4         2
# 158020  services    other  ...            5       3       3       3         3
# 158021  services    other  ...            4       1       3       4         5
# 158022  services    other  ...            2       3       3       3         5
#
#        absences_y G1_y G2_y G3_y _merge
# 0               6    5    6    6   both
# 1               4    5    5    6   both
# 2              10    7    8   10   both
# 3               2   15   14   15   both
# 4               4    6   10   10   both
# 5              10   15   15   15   both
# 6               0   12   12   11   both
# 7               6    6    5    6   both
# 8               0   16   18   19   both
# 9               0   14   15   15   both
# 10              0   10    8    9   both
# 11              4   10   12   12   both
# 12              2   14   14   14   both
# 13              2   10   10   11   both
# 14              0   14   16   16   both
# 15              4   14   14   14   both
# 16              6   13   14   14   both
# 17              4    8   10   10   both
# 18             16    6    5    5   both
# 19              4    8   10   10   both
# 20              0   13   14   15   both
# 21              0   12   15   15   both
# 22              2   15   15   16   both
# 23              0   13   13   12   both
# 24              2   10    9    8   both
# 25             14    6    9    8   both
# 26              2   12   12   11   both
# 27              4   15   16   15   both
# 28              4   11   11   11   both
# 29             16   10   12   11   both
# ...           ...  ...  ...  ...    ...
# 157993          4   10   10   10   both
# 157994          0   13   13   13   both
# 157995          0    7    6    0   both
# 157996          0   11   10   10   both
# 157997         10   14   12   11   both
# 157998          4    7    7    9   both
# 157999          3   14   12   12   both
# 158000          8   13   11   11   both
# 158001         14    6    5    5   both
# 158002          0   19   18   19   both
# 158003          2    8    8   10   both
# 158004          4   15   14   15   both
# 158005          4    8    9   10   both
# 158006          0   15   15   15   both
# 158007         17   10   10   10   both
# 158008          4   15   14   14   both
# 158009          5    7    6    7   both
# 158010          2   11   11   10   both
# 158011          0    6    5    0   both
# 158012         14    6    5    5   both
# 158013          2   10    9   10   both
# 158014          7    6    5    6   both
# 158015          0    7    5    0   both
# 158016          0    7    9    8   both
# 158017          0    6    5    0   both
# 158018         11    9    9    9   both
# 158019          3   14   16   16   both
# 158020          3   10    8    7   both
# 158021          0   11   12   10   both
# 158022          5    8    9    9   both
#
# [158023 rows x 66 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df=df.loc[:,'school':'guardian_x']
df.head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F     18         U       GT3         A       4       4  at_home
# 1     GP     F     18         U       GT3         A       4       4  at_home
# 2     GP     F     18         U       GT3         A       4       4  at_home
# 3     GP     F     18         U       GT3         A       4       4  at_home
# 4     GP     F     18         U       GT3         A       4       4  at_home
#
#     Fjob_x reason_x guardian_x
# 0  teacher   course     mother
# 1  teacher   course     mother
# 2  teacher   course     mother
# 3  teacher   course     mother
# 4  teacher   course     mother

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
cap=lambda x:x.upper()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df['Mjob_x'].apply(cap)
df['Fjob_x'].apply(cap)
# Out:
# 0         TEACHER
# 1         TEACHER
# 2         TEACHER
# 3         TEACHER
# 4         TEACHER
# 5         TEACHER
# 6         TEACHER
# 7         TEACHER
# 8         TEACHER
# 9         TEACHER
# 10        TEACHER
# 11        TEACHER
# 12        TEACHER
# 13        TEACHER
# 14        TEACHER
# 15        TEACHER
# 16        TEACHER
# 17        TEACHER
# 18        TEACHER
# 19        TEACHER
# 20        TEACHER
# 21        TEACHER
# 22        TEACHER
# 23        TEACHER
# 24        TEACHER
# 25        TEACHER
# 26        TEACHER
# 27        TEACHER
# 28        TEACHER
# 29        TEACHER
#            ...
# 157993      OTHER
# 157994      OTHER
# 157995      OTHER
# 157996      OTHER
# 157997      OTHER
# 157998      OTHER
# 157999      OTHER
# 158000      OTHER
# 158001      OTHER
# 158002      OTHER
# 158003      OTHER
# 158004      OTHER
# 158005      OTHER
# 158006      OTHER
# 158007      OTHER
# 158008      OTHER
# 158009      OTHER
# 158010      OTHER
# 158011      OTHER
# 158012      OTHER
# 158013      OTHER
# 158014      OTHER
# 158015      OTHER
# 158016      OTHER
# 158017      OTHER
# 158018      OTHER
# 158019      OTHER
# 158020      OTHER
# 158021      OTHER
# 158022      OTHER
# Name: Fjob_x, Length: 158023, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail()
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 158018     MS     M     18         R       LE3         T       3       2
# 158019     MS     M     18         R       LE3         T       3       2
# 158020     MS     M     18         R       LE3         T       3       2
# 158021     MS     M     18         R       LE3         T       3       2
# 158022     MS     M     18         R       LE3         T       3       2
#
#           Mjob_x Fjob_x reason_x guardian_x
# 158018  services  other   course     mother
# 158019  services  other   course     mother
# 158020  services  other   course     mother
# 158021  services  other   course     mother
# 158022  services  other   course     mother

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df['Mjob_x']=df['Mjob_x'].apply(cap)
df['Fjob_x']=df['Fjob_x'].apply(cap)
df.head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F     18         U       GT3         A       4       4  AT_HOME
# 1     GP     F     18         U       GT3         A       4       4  AT_HOME
# 2     GP     F     18         U       GT3         A       4       4  AT_HOME
# 3     GP     F     18         U       GT3         A       4       4  AT_HOME
# 4     GP     F     18         U       GT3         A       4       4  AT_HOME
#
#     Fjob_x reason_x guardian_x
# 0  TEACHER   course     mother
# 1  TEACHER   course     mother
# 2  TEACHER   course     mother
# 3  TEACHER   course     mother
# 4  TEACHER   course     mother

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if x>=18:
        return True
    else:
        return False

# %%
df['legal_drinker'] = df['age_x'].apply(majority)
df.head(20)
# Out:
#    school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0      GP     F     18         U       GT3         A       4       4  AT_HOME
# 1      GP     F     18         U       GT3         A       4       4  AT_HOME
# 2      GP     F     18         U       GT3         A       4       4  AT_HOME
# 3      GP     F     18         U       GT3         A       4       4  AT_HOME
# 4      GP     F     18         U       GT3         A       4       4  AT_HOME
# 5      GP     F     18         U       GT3         A       4       4  AT_HOME
# 6      GP     F     18         U       GT3         A       4       4  AT_HOME
# 7      GP     F     18         U       GT3         A       4       4  AT_HOME
# 8      GP     F     18         U       GT3         A       4       4  AT_HOME
# 9      GP     F     18         U       GT3         A       4       4  AT_HOME
# 10     GP     F     18         U       GT3         A       4       4  AT_HOME
# 11     GP     F     18         U       GT3         A       4       4  AT_HOME
# 12     GP     F     18         U       GT3         A       4       4  AT_HOME
# 13     GP     F     18         U       GT3         A       4       4  AT_HOME
# 14     GP     F     18         U       GT3         A       4       4  AT_HOME
# 15     GP     F     18         U       GT3         A       4       4  AT_HOME
# 16     GP     F     18         U       GT3         A       4       4  AT_HOME
# 17     GP     F     18         U       GT3         A       4       4  AT_HOME
# 18     GP     F     18         U       GT3         A       4       4  AT_HOME
# 19     GP     F     18         U       GT3         A       4       4  AT_HOME
#
#      Fjob_x reason_x guardian_x  legal_drinker
# 0   TEACHER   course     mother           True
# 1   TEACHER   course     mother           True
# 2   TEACHER   course     mother           True
# 3   TEACHER   course     mother           True
# 4   TEACHER   course     mother           True
# 5   TEACHER   course     mother           True
# 6   TEACHER   course     mother           True
# 7   TEACHER   course     mother           True
# 8   TEACHER   course     mother           True
# 9   TEACHER   course     mother           True
# 10  TEACHER   course     mother           True
# 11  TEACHER   course     mother           True
# 12  TEACHER   course     mother           True
# 13  TEACHER   course     mother           True
# 14  TEACHER   course     mother           True
# 15  TEACHER   course     mother           True
# 16  TEACHER   course     mother           True
# 17  TEACHER   course     mother           True
# 18  TEACHER   course     mother           True
# 19  TEACHER   course     mother           True

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
def multi_10(x):
    if type(x) is int:
        return x*10
    return x

# %%
df.applymap(lambda x:multi_10(x)).head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F    180         U       GT3         A      40      40  AT_HOME
# 1     GP     F    180         U       GT3         A      40      40  AT_HOME
# 2     GP     F    180         U       GT3         A      40      40  AT_HOME
# 3     GP     F    180         U       GT3         A      40      40  AT_HOME
# 4     GP     F    180         U       GT3         A      40      40  AT_HOME
#
#     Fjob_x reason_x guardian_x  legal_drinker
# 0  TEACHER   course     mother           True
# 1  TEACHER   course     mother           True
# 2  TEACHER   course     mother           True
# 3  TEACHER   course     mother           True
# 4  TEACHER   course     mother           True
